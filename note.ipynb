# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('employees/emp2.jpeg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) 

###BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions =  DeepFace.analyze(img, 
        actions = [ 'emotion']
)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  3.84it/s]

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
dfs = DeepFace.find(
    img,
   ## img_path = "img1.jpg", 
    db_path = "employees")
# Out:
# WARNING: Representations for images in employees folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  4  representations found in  representations_vgg_face.pkl
# find function lasts  0.6811840534210205  seconds

# %%
dfs
# Out:
# [              identity  source_x  source_y  source_w  source_h  \
#  0  employees/emp2.jpeg        96        24        72        72
#  1  employees/emp1.jpeg        96        24        72        72
#  2  employees/emp3.jpeg        96        24        72        72
#
#     VGG-Face_cosine
#  0     4.440892e-16
#  1     2.728982e-01
#  2     3.935545e-01  ]

# %%
print(dfs)
# Out:
# [              identity  source_x  source_y  source_w  source_h  \
# 0  employees/emp2.jpeg        96        24        72        72
# 1  employees/emp1.jpeg        96        24        72        72
# 2  employees/emp3.jpeg        96        24        72        72
#
#    VGG-Face_cosine
# 0     4.440892e-16
# 1     2.728982e-01
# 2     3.935545e-01  ]

# %%
img = (dfs[0]["identity"][0])
img = cv2.imread(img)

# %%
plt.imshow(img)
